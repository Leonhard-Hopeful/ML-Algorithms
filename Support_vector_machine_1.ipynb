# %% [markdown]
# <a href="https://colab.research.google.com/github/Leonhard-Hopeful/ML-Algorithms/blob/main/Support_vector_machine_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn import metrics

# %%
# Load the Iris dataset
iris = datasets.load_iris()
X, y = iris.data, iris.target

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Create an SVM classifier
clf = svm.SVC(kernel='linear') # You can change the kernel (e.g., 'rbf', 'poly')

# %%
# Train the classifier
clf.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
# Make predictions on the test set
y_pred = clf.predict(X_test)
y_pred
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0, 2, 1, 0, 2, 2, 1, 0, 2, 1, 1, 2, 0, 2, 0,
#        0])

# %%
# Evaluate the model
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
print("Precision:", metrics.precision_score(y_test, y_pred, average='weighted')) # Use weighted for multi-class
print("Recall:", metrics.recall_score(y_test, y_pred, average='weighted')) # Use weighted for multi-class
print("F1-score:", metrics.f1_score(y_test, y_pred, average='weighted')) # Use weighted for multi-class
# Out:
# Accuracy: 0.9777777777777777
# Precision: 0.9796296296296295
# Recall: 0.9777777777777777
# F1-score: 0.9779434092477569

# %%
# Classification report
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.94      0.97        18
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %%
# Confusion Matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
